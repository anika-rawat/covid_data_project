# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data_abridged_counties = pd.read_csv('abridged_counties.csv')
#some numbers and variables are by state vs others vary by county
data_abridged_counties
# Out:
#      countyFIPS  STATEFP  COUNTYFP                         CountyName  \
# 0         01001      1.0       1.0                            Autauga
# 1         01003      1.0       3.0                            Baldwin
# 2         01005      1.0       5.0                            Barbour
# 3         01007      1.0       7.0                               Bibb
# 4         01009      1.0       9.0                             Blount
# 5         01011      1.0      11.0                            Bullock
# 6         01013      1.0      13.0                             Butler
# 7         01015      1.0      15.0                            Calhoun
# 8         01017      1.0      17.0                           Chambers
# 9         01019      1.0      19.0                           Cherokee
# 10        01021      1.0      21.0                            Chilton
# 11        01023      1.0      23.0                            Choctaw
# ...

# %%
print(data_abridged_counties.shape)
data_abridged_counties.columns
# Out:
# (3244, 87)
# Index(['countyFIPS', 'STATEFP', 'COUNTYFP', 'CountyName', 'StateName', 'State',
#        'lat', 'lon', 'POP_LATITUDE', 'POP_LONGITUDE', 'CensusRegionName',
#        'CensusDivisionName', 'Rural-UrbanContinuumCode2013',
#        'PopulationEstimate2018', 'PopTotalMale2017', 'PopTotalFemale2017',
#        'FracMale2017', 'PopulationEstimate65+2017',
#        'PopulationDensityperSqMile2010', 'CensusPopulation2010',
#        'MedianAge2010', '#EligibleforMedicare2018',
#        'MedicareEnrollment,AgedTot2017', '3-YrDiabetes2015-17',
#        'DiabetesPercentage', 'HeartDiseaseMortality', 'StrokeMortality',
#        'Smokers_Percentage', 'RespMortalityRate2014', '#FTEHospitalTotal2017',
#        'TotalM.D.'s,TotNon-FedandFed2017', '#HospParticipatinginNetwork2017',
#        '#Hospitals', '#ICU_beds', 'dem_to_rep_ratio', 'PopMale<52010',
#        'PopFmle<52010', 'PopMale5-92010', 'PopFmle5-92010', 'PopMale10-142010',
# ...

# %%
#find counties per state 
by_state = data_abridged_counties.groupby('StateName').count()
by_state
# Out:
#            countyFIPS  STATEFP  COUNTYFP  CountyName  State  lat  lon  \
# StateName
# AK                 32       29        29          32      0    0    0
# AL                 67       67        67          67     67   67   67
# AR                 75       75        75          75     75   75   75
# AS                  5        0         0           5      0    0    0
# AZ                 15       15        15          15     15   15   15
# CA                 58       58        58          58     58   58   58
# CO                 64       64        64          64     64   64   64
# CT                  8        8         8           8      8    8    8
# DC                  1        1         1           1      1    1    1
# DE                  3        3         3           3      3    3    3
# FL                 68       67        67          68     67   67   67
# GA                159      159       159         159    159  159  159
# ...

# %%
data_abridged_counties.drop(columns = ['countyFIPS',
 'STATEFP',
 'COUNTYFP',
 'State',
 'lat',
 'lon',
 'POP_LATITUDE',
 'POP_LONGITUDE'])
data_abridged_counties.isnull().sum(axis=1)
# Out:
# 0        8
# 1        6
# 2        8
# 3        8
# 4        5
# 5        9
# 6        6
# 7        3
# 8        9
# 9        7
# 10       6
# 11       8
# 12       8
# 13       8
# 14       8
# 15      10
# 16       7
# 17       8
# 18       8
# 19       6
# 20       9
# 21       4
# 22       6
# 23       5
# 24       4
# 25       7
# 26       6
# 27       3
# 28       8
# 29       7
#         ..
# 3214    21
# 3215    19
# 3216    21
# 3217    20
# 3218    22
# 3219    19
# 3220    23
# 3221    23
# 3222    21
# 3223    24
# 3224    23
# 3225    23
# 3226    21
# 3227    25
# 3228    21
# 3229    37
# 3230    46
# 3231    37
# 3232    11
# 3233     3
# 3234    20
# 3235    23
# 3236    17
# 3237    20
# 3238    23
# 3239    21
# 3240    25
# 3241    22
# 3242    84
# 3243    84
# Length: 3244, dtype: int64

# %%
#rows with an insane amount of NaNs but its dependent but usually rows with almost full amt of nans we dont want...
#first take out columns we dont really want to use though 
data_abridged_counties[data_abridged_counties.isnull().sum(axis=1) >50]
# Out:
#      countyFIPS  STATEFP  COUNTYFP                       CountyName StateName  \
# 85        02201      NaN       NaN  Prince of Wales-Outer Ketchikan        AK
# 87        02232      NaN       NaN            Skagway-Hoonah-Angoon        AK
# 91        02280      NaN       NaN              Wrangell-Petersburg        AK
# 329       12025      NaN       NaN                             Dade        FL
# 1650      30113      NaN       NaN             Yellowstone Nat Park        MT
# 2414      46113     46.0     113.0                          Shannon        SD
# 2918      51560      NaN       NaN               Clifton Forge City        VA
# 2946      51780      NaN       NaN                South Boston City        VA
# 3142      60010      NaN       NaN                          Unknown        AS
# 3143      60020      NaN       NaN                            Manua        AS
# 3144      60020      NaN       NaN                              Ofu        AS
# ...

# %%
death_data = pd.read_csv('time_series_covid19_deaths_US.csv')
death_data
# Out:
#            UID iso2 iso3  code3     FIPS  \
# 0           16   AS  ASM     16     60.0
# 1          316   GU  GUM    316     66.0
# 2          580   MP  MNP    580     69.0
# 3          630   PR  PRI    630     72.0
# 4          850   VI  VIR    850     78.0
# 5     84001001   US  USA    840   1001.0
# 6     84001003   US  USA    840   1003.0
# 7     84001005   US  USA    840   1005.0
# 8     84001007   US  USA    840   1007.0
# 9     84001009   US  USA    840   1009.0
# 10    84001011   US  USA    840   1011.0
# 11    84001013   US  USA    840   1013.0
# 12    84001015   US  USA    840   1015.0
# 13    84001017   US  USA    840   1017.0
# 14    84001019   US  USA    840   1019.0
# 15    84001021   US  USA    840   1021.0
# 16    84001023   US  USA    840   1023.0
# 17    84001025   US  USA    840   1025.0
# 18    84001027   US  USA    840   1027.0
# 19    84001029   US  USA    840   1029.0
# 20    84001031   US  USA    840   1031.0
# 21    84001033   US  USA    840   1033.0
# ...

# %%
print(death_data.shape)
death_data.columns
# Out:
# (3255, 100)
# Index(['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2', 'Province_State',
#        'Country_Region', 'Lat', 'Long_', 'Combined_Key', 'Population',
#        '1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        '1/28/20', '1/29/20', '1/30/20', '1/31/20', '2/1/20', '2/2/20',
#        '2/3/20', '2/4/20', '2/5/20', '2/6/20', '2/7/20', '2/8/20', '2/9/20',
#        '2/10/20', '2/11/20', '2/12/20', '2/13/20', '2/14/20', '2/15/20',
#        '2/16/20', '2/17/20', '2/18/20', '2/19/20', '2/20/20', '2/21/20',
#        '2/22/20', '2/23/20', '2/24/20', '2/25/20', '2/26/20', '2/27/20',
#        '2/28/20', '2/29/20', '3/1/20', '3/2/20', '3/3/20', '3/4/20', '3/5/20',
#        '3/6/20', '3/7/20', '3/8/20', '3/9/20', '3/10/20', '3/11/20', '3/12/20',
#        '3/13/20', '3/14/20', '3/15/20', '3/16/20', '3/17/20', '3/18/20',
#        '3/19/20', '3/20/20', '3/21/20', '3/22/20', '3/23/20', '3/24/20',
# ...

# %%
#fill in state names in county table and merge with death table 
#visualize death time series 
#figure out which counties and states had most reported deaths and then analyze those 
#figure out if certain counties or states had more rapid rates of deaths

# %%
covid_case_data = pd.read_csv('time_series_covid19_confirmed_US.csv')
covid_case_data
# Out:
#            UID iso2 iso3  code3     FIPS  \
# 0           16   AS  ASM     16     60.0
# 1          316   GU  GUM    316     66.0
# 2          580   MP  MNP    580     69.0
# 3          630   PR  PRI    630     72.0
# 4          850   VI  VIR    850     78.0
# 5     84001001   US  USA    840   1001.0
# 6     84001003   US  USA    840   1003.0
# 7     84001005   US  USA    840   1005.0
# 8     84001007   US  USA    840   1007.0
# 9     84001009   US  USA    840   1009.0
# 10    84001011   US  USA    840   1011.0
# 11    84001013   US  USA    840   1013.0
# 12    84001015   US  USA    840   1015.0
# 13    84001017   US  USA    840   1017.0
# 14    84001019   US  USA    840   1019.0
# 15    84001021   US  USA    840   1021.0
# 16    84001023   US  USA    840   1023.0
# 17    84001025   US  USA    840   1025.0
# 18    84001027   US  USA    840   1027.0
# 19    84001029   US  USA    840   1029.0
# 20    84001031   US  USA    840   1031.0
# 21    84001033   US  USA    840   1033.0
# ...

# %%
print(covid_case_data.shape)
covid_case_data.columns
# Out:
# (3255, 99)
# Index(['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2', 'Province_State',
#        'Country_Region', 'Lat', 'Long_', 'Combined_Key', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20', '1/28/20', '1/29/20',
#        '1/30/20', '1/31/20', '2/1/20', '2/2/20', '2/3/20', '2/4/20', '2/5/20',
#        '2/6/20', '2/7/20', '2/8/20', '2/9/20', '2/10/20', '2/11/20', '2/12/20',
#        '2/13/20', '2/14/20', '2/15/20', '2/16/20', '2/17/20', '2/18/20',
#        '2/19/20', '2/20/20', '2/21/20', '2/22/20', '2/23/20', '2/24/20',
#        '2/25/20', '2/26/20', '2/27/20', '2/28/20', '2/29/20', '3/1/20',
#        '3/2/20', '3/3/20', '3/4/20', '3/5/20', '3/6/20', '3/7/20', '3/8/20',
#        '3/9/20', '3/10/20', '3/11/20', '3/12/20', '3/13/20', '3/14/20',
#        '3/15/20', '3/16/20', '3/17/20', '3/18/20', '3/19/20', '3/20/20',
#        '3/21/20', '3/22/20', '3/23/20', '3/24/20', '3/25/20', '3/26/20',
# ...

# %%
#visualize cases vs deaths in each state and county over time 
#figure out which cases had most or lease cases confirmed 
#figure out if certain counties or states had more rapid rates of diagnoses 
#plot social gatherings vs confirmed case correlation per region + maybe higher amt of deaths? 
#social gatherings vs pop size tho

# %%
states_data = pd.read_csv('4.18states.csv')
states_data
# Out:
#                 Province_State  Country_Region          Last_Update      Lat  \
# 0                      Alabama              US  2020-04-18 22:32:47  32.3182
# 1                       Alaska              US  2020-04-18 22:32:47  61.3707
# 2               American Samoa              US                  NaN -14.2710
# 3                      Arizona              US  2020-04-18 22:32:47  33.7298
# 4                     Arkansas              US  2020-04-18 22:32:47  34.9697
# 5                   California              US  2020-04-18 22:32:47  36.1162
# 6                     Colorado              US  2020-04-18 22:32:47  39.0598
# 7                  Connecticut              US  2020-04-18 22:32:47  41.5978
# 8                     Delaware              US  2020-04-18 22:32:47  39.3185
# 9             Diamond Princess              US  2020-04-18 22:32:47      NaN
# 10        District of Columbia              US  2020-04-18 22:32:47  38.8974
# ...

# %%
print(states_data.shape)
states_data.columns
# Out:
# (140, 18)
# Index(['Province_State', 'Country_Region', 'Last_Update', 'Lat', 'Long_',
#        'Confirmed', 'Deaths', 'Recovered', 'Active', 'FIPS', 'Incident_Rate',
#        'People_Tested', 'People_Hospitalized', 'Mortality_Rate', 'UID', 'ISO3',
#        'Testing_Rate', 'Hospitalization_Rate'],
#       dtype='object')

# %%
#these have many countries so how many countries?
by_country = states_data.groupby('Country_Region').count()
by_country
# Out:
#                 Province_State  Last_Update  Lat  Long_  Confirmed  Deaths  \
# Country_Region
# Australia                    8            0    8      8          8       8
# Canada                      14            0   12     12         14      14
# China                       33            0   33     33         33      33
# Denmark                      2            0    2      2          2       2
# France                      10            0   10     10         10      10
# Netherlands                  4            0    4      4          4       4
# US                          59           57   56     56         59      59
# United Kingdom              10            0   10     10         10      10
#
#                 Recovered  Active  FIPS  Incident_Rate  People_Tested  \
# Country_Region
# Australia               8       8     0              8              0
# Canada                 14      14     0             12              0
# ...

# %%
#check to see if this timeline is same as other data set 
#can check things like mortality rates against historical data from other data set idk 
#figure out how many people tested vs hospitalized per county and how fast with latest update with respect to
#the economic status of that county or region? 
#people tested amounts in certain counties with regards to accessibility to hospitals etc (data point in abridged)
